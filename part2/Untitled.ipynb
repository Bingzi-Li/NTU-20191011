# %%
import pandas as pd
import spacy
import os.path

review_path = '../data/reviewSelected100.json'
os.path.exists(review_path)

# Get the reviews text, stores in array
review_df = pd.read_json(review_path, lines=True)
review_df.head()
# Group data by business_id
review_df_groupby_bid = review_df.groupby('business_id')

review_bid_list = []
review_bid_dict = {}

for bid, bid_df in review_df_groupby_bid:
    review_bid_list.append(bid)
    review_bid_dict[bid] = bid_df.reset_index()

# Get the reviews text of certain business_id, stores in array
review_bid_text = []
for i in range(100):
    review_bid_text.append(review_bid_dict[review_bid_list[27]]['text'][i])

arr = review_bid_text

#print(review_bid_text)

#print(review_bid_list[27]) # 4 14 18 19 27

# arr = ["The food is good", "Give me some good food", "The restaurant's food is very good", "The food in this restaurant is surprisingly good"]

nlp = spacy.load('en')

# Create a dictionary with Key:Value pair - (Noun, Adjective):count
countdict={}

# k loop traverse the array of reviews
for k in range(0, 10):
    doc = nlp(arr[k])

    # i loop traverse to find all the Noun, Adjective pairs
    for i, token in enumerate(doc):
        if token.pos_ not in ('NOUN', 'PROPN'):
            continue

        # j loop to update the dictionary, by adding unseen pairs and increment count of seen pairs
        for j in range(i + 1, len(doc)):
            if doc[j].pos_ == 'ADJ':
                key = (str(token), str(doc[j]))
                # print(countdict.keys())
                if key in countdict.keys():
                    countdict[key] = countdict[key]+1
                else:
                    countdict[key] = 1
                break

    for i, token in enumerate(doc):
        if token.pos_ not in ('ADJ'):
            continue

        # j loop to update the dictionary, by adding unseen pairs and increment count of seen pairs
        for j in range(i + 1, len(doc)):
            if doc[j].pos_ == 'NOUN' or doc[j].pos_ == 'PROPN':
                key = (str(doc[j]), str(token))
                # print(countdict.keys())
                if key in countdict.keys():
                    countdict[key] = countdict[key]+1
                else:
                    countdict[key] = 1
                break

# print the (Noun, Adjective) with its count in a sorted order
a1_sorted_keys = sorted(countdict, key=countdict.get, reverse=True)
for r in a1_sorted_keys:
    print(r, countdict[r])
# Out:
# ('_', 'free') 4
# ('chicken', 'grilled') 3
# ('Chico', 'former') 2
# ('lousy', 'former') 2
# ('chef', 'New') 2
# ('chicken', 'delicious') 2
# ('place', 'better') 2
# ('lots', 'enough') 2
# ('type', 'better') 2
# ('tostada', 'favorite') 2
# ('Tacos', 'former') 1
# ('Grill', 'former') 1
# ('place', 'former') 1
# ('look', 'former') 1
# ('disdain', 'former') 1
# ('face', 'former') 1
# ('Lousy', 'former') 1
# ('favorite', 'much') 1
# ('mine', 'much') 1
# ('list', 'much') 1
# ('carne', 'much') 1
# ('asado', 'much') 1
# ('fatty', 'much') 1
# ('grisley', 'much') 1
# ('sp', 'much') 1
# ('chicken', 'much') 1
# ('highlight', 'much') 1
# ('meal', 'much') 1
# ('favorite', 'former') 1
# ('place', 'mediocre') 1
# ('ripoff', 'mediocre') 1
# ('food', 'mediocre') 1
# ('arroz', 'large') 1
# ('con', 'large') 1
# ('pollo', 'large') 1
# ('drink', 'okay') 1
# ('bucks', 'okay') 1
# ('lot', 'okay') 1
# ('couple', 'okay') 1
# ('salsa', 'okay') 1
# ('cups', 'okay') 1
# ('seat', 'okay') 1
# ('salsas', 'okay') 1
# ('casera', 'devoid') 1
# ('Herdez', 'devoid') 1
# ('Salsa', 'devoid') 1
# ('Casera', 'devoid') 1
# ('grocery', 'devoid') 1
# ('store', 'devoid') 1
# ('lunch', 'devoid') 1
# ('arroz', 'devoid') 1
# ('con', 'devoid') 1
# ('pollo', 'devoid') 1
# ('rice', 'devoid') 1
# ('flavor', 'small') 1
# ('chicken', 'small') 1
# ('arroz', 'mediocre') 1
# ('drink', 'large') 1
# ('casera', 'okay') 1
# ('flavor', 'devoid') 1
# ('portion', 'small') 1
# ('fan', 'New') 1
# ('chicos', 'New') 1
# ('management', 'different') 1
# ('food', 'different') 1
# ('place', 'different') 1
# ('chicken', 'Good') 1
# ('breakfast', 'Good') 1
# ('burritos', 'Good') 1
# ('fan', 'HUGE') 1
# ('management', 'New') 1
# ('chicken', 'different') 1
# ('chicken', 'fresh') 1
# ('place', 'Good') 1
# ('Yelp', 'prior') 1
# ('hole', 'prior') 1
# ('wall', 'prior') 1
# ('Nearby', 'prior') 1
# ('search', 'prior') 1
# ('reviewers', 'okay') 1
# ('burrito', 'delicious') 1
# ('burritos', 'best') 1
# ('tortilla', 'best') 1
# ('tortillas', 'best') 1
# ('time', 'great') 1
# ('salsa', 'small') 1
# ('bar', 'small') 1
# ('neighborhood', 'full') 1
# ('gem', 'full') 1
# ('burrito', 'full') 1
# ('meat', 'smoky') 1
# ('flavor', 'extra') 1
# ('grill', 'extra') 1
# ('chicken', 'extra') 1
# ('rice', 'enough') 1
# ('cheese', 'good') 1
# ('salsa', 'good') 1
# ('chip', 'better') 1
# ('Baja', 'better') 1
# ('Fresh', 'better') 1
# ('ingredients', 'true') 1
# ('flare', 'mariachi') 1
# ('music', 'great') 1
# ('counter', 'great') 1
# ('number', 'great') 1
# ('staff', 'great') 1
# ('reviewers', 'prior') 1
# ('chicken', 'okay') 1
# ('burritos', 'delicious') 1
# ('time', 'best') 1
# ('time', 'long') 1
# ('salsa', 'great') 1
# ('neighborhood', 'small') 1
# ('neighborhood', 'fresh') 1
# ('neighborhood', 'great') 1
# ('neighborhood', 'local') 1
# ('meat', 'full') 1
# ('meat', 'dark') 1
# ('flavor', 'smoky') 1
# ('rice', 'extra') 1
# ('rice', 'flavorful') 1
# ('rice', 'delicious') 1
# ('rice', 'Mexican') 1
# ('cheese', 'enough') 1
# ('chip', 'good') 1
# ('ingredients', 'better') 1
# ('flare', 'true') 1
# ('flare', 'Mexican') 1
# ('music', 'mariachi') 1
# ('clearing', 'great') 1
# ('chicken', 'giant') 1
# ('works', 'giant') 1
# ('burrito', 'enough') 1
# ('beans', 'enough') 1
# ('chicken', 'decent') 1
# ('hochata', 'decent') 1
# ('burrito', 'giant') 1
# ('chicken', 'enough') 1
# ('MMM', 'delicious') 1
# ('Chicos', 'delicious') 1
# ('years', 'delicious') 1
# ('places', 'better') 1
# ('town', 'better') 1
# ('guests', 'better') 1
# ('pay', 'better') 1
# ('counter', 'better') 1
# ('type', 'free') 1
# ('bertos', 'free') 1
# ('lard', 'free') 1
# ('beans', 'several') 1
# ('salsa', 'several') 1
# ('bar', 'several') 1
# ('types', 'generous') 1
# ('chips', 'generous') 1
# ('meal', 'generous') 1
# ('portions', 'generous') 1
# ('california', 'favorite') 1
# ('burro', 'favorite') 1
# ('pound', 'favorite') 1
# ('tostadas', 'favorite') 1
# ('shell', 'favorite') 1
# ('mix', 'favorite') 1
# ('taco', 'favorite') 1
# ('salad', 'favorite') 1
# ('veggie', 'favorite') 1
# ('guac', 'sour') 1
# ('cream', 'best') 1
# ('food', 'good') 1
# ('California', 'good') 1
# ('burro', 'good') 1
# ('quesedillas', 'good') 1
# ('boyfriends', 'upbeat') 1
# ('mom', 'upbeat') 1
# ('Apache', 'upbeat') 1
# ('Junction', 'upbeat') 1
# ('steak', 'upbeat') 1
# ('quesedilla', 'upbeat') 1
# ('restaurant', 'upbeat') 1
# ('music', 'Good') 1
# ('playing', 'Good') 1
# ('location', 'enough') 1
# ('parking', 'enough') 1
# ('right', 'enough') 1
# ('Starbucks', 'enough') 1
# ('review', 'enough') 1
# ('places', 'delicious') 1
# ('beans', 'free') 1
# ('types', 'several') 1
# ('types', 'different') 1
# ('california', 'generous') 1
# ('guac', 'favorite') 1
# ('cream', 'sour') 1
# ('food', 'best') 1
# ('food', 'mexican') 1
# ('boyfriends', 'good') 1
# ('music', 'upbeat') 1
# ('music', 'mexican') 1
# ('location', 'Good') 1
# ('cops', 'enough') 1
# ('place', 'decent') 1
# ('food', 'delicious') 1
# ('greasey', 'absolute') 1
# ('foods', 'absolute') 1
# ('Asada', 'absolute') 1
# ('Platter', 'absolute') 1
# ('Achiote', 'absolute') 1
# ('Chicken', 'absolute') 1
# ('Salad', 'absolute') 1
# ('food', 'decent') 1
# ('food', 'fast') 1
# ('food', 'Mexican') 1
# ('greasey', 'delicious') 1
# ('favorite', 'absolute') 1
# ('El', 'delicious') 1
# ('Pollo', 'delicious') 1
# ('plate', 'delicious') 1
# ('Chicken', 'different') 1
# ('rice', 'different') 1
# ('beans', 'different') 1
# ('flour', 'different') 1
# ('tortillas', 'different') 1
# ('Salsa', 'different') 1
# ('bar', 'different') 1
# ('alot', 'different') 1
# ('Chicken', 'delicious') 1
# ('choices', 'different') 1
